# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %run ../Preprocessing/LBP_preprocessing.ipynb 
# %run ../FeatureExtraction/LBP_Feature_Extraction.ipynb

# %%
def LBP_box(image):
   preprocessed_image = hog_preprocessing(image)
   hog_feature_vector = LBP_Feature_Extraction(preprocessed_image,32, 32*8) 
   return hog_feature_vector

# %%
# image = cv2.imread('E:/2nd term 3rd year/Neural Network/Project/men/'+str(2)+'/'+str(2)+'_men ('+str(5)+').JPG', cv2.IMREAD_UNCHANGED)
# des=LBP_box(image)
# print(des)
# print(len(des))
# Out:
# [9.04584734e-01 1.54824772e-02 7.20115218e-04 1.21219395e-02
#  8.40134422e-04 2.40038406e-04 2.40038406e-04 1.16418627e-02
#  4.80076812e-04 2.40038406e-04 0.00000000e+00 0.00000000e+00
#  4.80076812e-04 1.20019203e-04 4.80076812e-04 8.76140182e-03
#  6.00096015e-04 0.00000000e+00 1.20019203e-04 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.40038406e-04 0.00000000e+00 0.00000000e+00 3.60057609e-04
#  3.60057609e-04 2.40038406e-04 4.80076812e-04 3.24051848e-03
#  3.60057609e-04 1.20019203e-04 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.20019203e-04 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 2.40038406e-04
#  7.20115218e-04 1.20019203e-04 0.00000000e+00 3.60057609e-04
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.60057609e-04 1.20019203e-04 0.00000000e+00 0.00000000e+00
# ...
